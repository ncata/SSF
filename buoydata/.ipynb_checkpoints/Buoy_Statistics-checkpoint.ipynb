# %% [markdown]
# # NDBC Statistics
#
# This notebook contains code used to view, manipulate, and analyze buoy data from buoys stationed in the Great Lakes and connected to the NDBC network

# %% [markdown]
# ### Initial Workflow
# Find buoy of interest in [NDCB Map](https://www.ndbc.noaa.gov/) --> In historical data, find the year of interest in the standard meteoroligical data category (note Great Lakes buoys do not collect spectral wave data) --> Save the .txt file and name it using the convention "exampleplace_year.txt" --> Using excel, convert exampleplace_year.txt to a .csv and replace all 99.00 values with NaN --> Load "exampleplace_year.csv" into pandas and display output to make sure it loaded correctly.

# %%
import pandas as pd

muskegon_2020 = pd.read_csv("muskegon_2020.csv")
muskegon_2020
# Out:
#       Column1 Column2 Column3 Column4 Column5 Column6 Column7 Column8 Column9  \
# 0         #YY      MM      DD      hh      mm    WDIR    WSPD     GST    WVHT
# 1         #yr      mo      dy      hr      mn    degT     m/s     m/s       m
# 2        2020      08      13      16      30     260     1.5     1.9    0.11
# 3        2020      08      13      16      40     282     1.9     2.3    0.35
# 4        2020      08      13      16      50     268     1.9     2.3    0.14
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 14265    2020      11      22      16      10     130     4.3     5.7    0.34
# 14266    2020      11      22      16      20     130     3.7     4.9    0.37
# 14267    2020      11      22      16      30     129     3.4     4.6    0.35
# 14268    2020      11      22      16      40     135     3.5     5.1    0.39
# 14269    2020      11      22      16      50     137     3.3     4.8    0.37
#
# ...

# %% [markdown]
# ### Remove Irrelvant Data

# %%
muskegon_2020.drop[[5,6,7,13,14,15,16,17], axis == 1, inplace == True] # There must be a better way to index through these
muskegon_2020
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a77fa7d59310> in <module>
# ----> 1 muskegon_2020.drop[[5,6,7,13,14,15,16,17], axis == 1, inplace == True] # There must be a better way to index through these
#       2 muskegon_2020
#
# NameError: name 'axis' is not defined
