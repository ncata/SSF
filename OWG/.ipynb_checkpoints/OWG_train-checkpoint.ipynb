# %% [markdown]
# # Optical Wave Gauging for Google Colab
#
# by Daniel Buscombe, daniel.buscombe@nau.edu
#
# This notebook is part of https://github.com/dbuscombe-usgs/OpticalWaveGauging_DNN
#
# ### Train an optical wave gage (OWG) to estimate wave height from an image
#
#
# First, enable a GPU runtime:
#
# In Colab, go to runtime > change runtime type > hardware accelerator: GPU
#
#
# Workflow:
#
# 1. Write a configuration file - this is how you interact with OWG functions
# 2. Download the data and model weights
# 3. Define the model
# 4. Generate test images and associated wave heights from the downloaded imagery
# 5. Use the model to estimate wave height for each image
# 6. Make plots

# %% [markdown]
# Import libraries

# %%
import numpy as np 
import pandas as pd 
import os, gc, requests, zipfile
import time, datetime, json
from glob import glob
from sklearn.model_selection import train_test_split

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# This notebook assumes you are in Google Colab. Therefore, switch to Tensorflow 2 and verify by printing the version, which should say '2.X.X' where X can be any number

# %%
#%tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import mean_absolute_error
# Out:
# 2.5.0

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Write the configuration file using the magic command 'writefile'

# %%
# %%writefile config_trainMC17trial4.json
# {
#   "samplewise_std_normalization" : true,
#   "samplewise_center"  : true,
#   "input_image_format" : "jpg",
#   "input_csv_file"     : "C:/njc/src/SSF/OWG/OWG_records/Trial3/mcyv22017trial3train.csv",
#   "category"           : "H",
#   "prc_lower_withheld": 0,
#   "prc_upper_withheld": 0,
#
#   "horizontal_flip"    : false,
#   "vertical_flip"      : false,
#   "rotation_range"     : 10,
#   "width_shift_range"  : 0.1,
#   "height_shift_range" : 0.1,
#   "shear_range"        : 0.05,
#   "zoom_range"         : 0.2,
#   "fill_mode"          : "reflect",
#
#   "img_size"           : 512,
#   "num_epochs"         : 200,
#   "test_size"          : 0.6,
#   "dropout_rate"       : 0.5,
#   "epsilon"            : 0.0001,
#   "min_lr"             : 0.0001,
#   "factor"             : 0.8
# }
# Out:
# Writing config_trainMC17trial4.json

# %% [markdown]
# Open the config file and read values into workspace. This might seem like a long-winded way of doing things -- and it is --- but this is how things are set up in the command line python scripts version of this workflow in `https://github.com/dbuscombe-usgs/OpticalWaveGauging_DNN/train_OWG.py` so it is maintained here for consistency

# %%
with open('config_trainMC17trial4.json') as f:    
    config = json.load(f)

# config variables
imsize    = int(config["img_size"])
num_epochs = int(config["num_epochs"]) 
test_size = float(config["test_size"])
height_shift_range = float(config["height_shift_range"])
width_shift_range = float(config["width_shift_range"])
rotation_range = float(config["rotation_range"])
samplewise_std_normalization = config["samplewise_std_normalization"]
horizontal_flip = config["horizontal_flip"]
vertical_flip = config["vertical_flip"]
samplewise_center = config["samplewise_center"]
shear_range = float(config["shear_range"])
zoom_range = float(config["zoom_range"])
dropout_rate = float(config["dropout_rate"])
epsilon = float(config["epsilon"])
min_lr = float(config["min_lr"])
factor = float(config["factor"])
input_image_format = config["input_image_format"]
input_csv_file = config["input_csv_file"]
category = config["category"] 
fill_mode = config["fill_mode"]
prc_lower_withheld = config['prc_lower_withheld'] 
prc_upper_withheld = config['prc_upper_withheld']
IMG_SIZE = (imsize, imsize)

# %%
image_dir = "C:/njc/src/mcyimgs/2017_imgprep3/view2"

# %%
def get_and_tidy_df(base_dir, input_csv_file, image_dir, category):
        df = pd.read_csv(os.path.join(base_dir, input_csv_file))
        df['path'] = df['id'].map(lambda x: os.path.join(base_dir,image_dir,'{}'.format(x)))
            
        df = df.rename(index=str, columns={" H": "H", " T": "T"})   
        
        if category == 'H':
            mean = df['H'].mean() 
            div = df['H'].std() 
            df['zscore'] = df['H'].map(lambda x: (x-mean)/div)
        elif category == 'T':
            mean = df['T'].mean() 
            div = df['T'].std() 
            df['zscore'] = df['T'].map(lambda x: (x-mean)/div)			
        else:
            print("Unknown category: "+str(category))
            print("Fix config file, exiting now ...")
            sys.exit()
        
        df.dropna(inplace = True)
        try:
            df = df.sort_values(by='time', axis=0)
        except:
            df = df.sort_values(by='id', axis=0)

        if category == 'H':
            df['category'] = pd.cut(df['H'], 10)
        else:
            df['category'] = pd.cut(df['T'], 8)
            
        df['index1'] = df.index; new_df = df.groupby(['category']).apply(lambda x: x.sample(int(len(df)/2), replace = True)).reset_index(drop = True)

        return new_df, df

# %% [markdown]
# Get a dataframe to generate test and train data from

# %%
# call the utils.py function get_and_tidy_df            	
new_df, df = get_and_tidy_df(os.getcwd(), input_csv_file, image_dir, category)

# %% [markdown]
# Get train and test splits and define the generator function that will do the image augmentation

# %%
print('New Data Size:', new_df.shape[0], 'Old Size:', df.shape[0])
      
train_df, valid_df = train_test_split(new_df, 
                    test_size = test_size, 
                    random_state = 2018,
                    stratify = new_df['category'])
print('train', train_df.shape[0], 'validation', valid_df.shape[0])

im_gen = ImageDataGenerator(samplewise_center=samplewise_center,
                samplewise_std_normalization=samplewise_std_normalization,
                horizontal_flip = horizontal_flip,  
                vertical_flip = vertical_flip, 
                height_shift_range = height_shift_range, 
                width_shift_range = width_shift_range, 
                rotation_range = rotation_range,
                shear_range = shear_range, 
                fill_mode = fill_mode,
                zoom_range= zoom_range)
# Out:
# New Data Size: 1770 Old Size: 355
# train 708 validation 1062

# %% [markdown]
# Make a generator from a dataframe

# %%
def gen_from_def(IMG_SIZE, df, image_dir, category, im_gen):

	gen = im_gen.flow_from_dataframe(dataframe=df,
								  directory=image_dir,
								  x_col="path",
								  y_col=category,
								  target_size=IMG_SIZE,
								  batch_size=len(df),
								  color_mode = 'grayscale',
								  shuffle=False,
								  class_mode='raw')
								  	
	ex_X, ex_Y = next(gen)
	return ex_X, ex_Y

# %% [markdown]
# Get the train and test images and associated wave heights. This takes a while

# %%
train_X, train_Y = gen_from_def(IMG_SIZE, train_df, image_dir, category, im_gen)
test_X, test_Y = gen_from_def(IMG_SIZE, valid_df, image_dir, category, im_gen)
# Out:
# Found 708 validated image filenames.
# Found 1062 validated image filenames.

# %%
batch_size = 13

weights_path='mcy_H_weights_trial4_'+str(batch_size)+'batch.best.nearshore.hdf5'	
      
print(weights_path)
# Out:
# mcy_H_weights_trial4_13batch.best.nearshore.hdf5

# %% [markdown]
# Create a model checkpoint, and training utilities such as early stopping, and reduce learning rate on a plateau in validaion loss

# %%
model_checkpoint = ModelCheckpoint(weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only = True)

reduceloss_plat = ReduceLROnPlateau(monitor='val_loss', factor=factor, patience=5, verbose=1, mode='auto', epsilon=epsilon, cooldown=5, min_lr=min_lr)
earlystop = EarlyStopping(monitor="val_loss", mode="min", patience=25) 
callbacks_list = [model_checkpoint, earlystop, reduceloss_plat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
# mean absolute error
def mae_metric(in_gt, in_pred):
    return mean_absolute_error(in_gt, in_pred)

# %% [markdown]
# Set model and print a summary

# %%
base_model = MobileNet(input_shape =  (IMG_SIZE[0], IMG_SIZE[1],1), include_top = False, weights = None)			
OWG = Sequential()
OWG.add(BatchNormalization(input_shape = (IMG_SIZE[0], IMG_SIZE[1],1)))
OWG.add(base_model)
OWG.add(BatchNormalization())
OWG.add(GlobalAveragePooling2D())
OWG.add(Dropout(0.5)) 
OWG.add(Dense(1, activation = 'linear' )) 

OWG.compile(optimizer = 'rmsprop', loss = 'mse', metrics = [mae_metric])
OWG.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 512, 512, 1)       4
# _________________________________________________________________
# mobilenet_1.00_512 (Function (None, 16, 16, 1024)      3228288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 1024)      4096
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# Total params: 3,233,413
# Trainable params: 3,209,475
# Non-trainable params: 23,938
# _________________________________________________________________

# %%
# %%time
history = OWG.fit(train_X, train_Y, batch_size=batch_size, 
                  validation_data = (test_X, test_Y),
                  epochs=num_epochs, callbacks = callbacks_list)

OWG.load_weights(weights_path)
# Out:
# Epoch 1/200
# 55/55 [==============================] - 36s 493ms/step - loss: 2.0079 - mae_metric: 0.8658 - val_loss: 0.5604 - val_mae_metric: 0.6443
#
# Epoch 00001: val_loss improved from inf to 0.56039, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 2/200
# 55/55 [==============================] - 25s 459ms/step - loss: 0.4777 - mae_metric: 0.5645 - val_loss: 0.7530 - val_mae_metric: 0.7151
#
# Epoch 00002: val_loss did not improve from 0.56039
# Epoch 3/200
# 55/55 [==============================] - 25s 463ms/step - loss: 0.3892 - mae_metric: 0.4977 - val_loss: 1.9748 - val_mae_metric: 1.1929
#
# Epoch 00003: val_loss did not improve from 0.56039
# Epoch 4/200
# 55/55 [==============================] - 25s 465ms/step - loss: 0.3338 - mae_metric: 0.4586 - val_loss: 3.6581 - val_mae_metric: 1.7617
#
# Epoch 00004: val_loss did not improve from 0.56039
# Epoch 5/200
# 55/55 [==============================] - 25s 465ms/step - loss: 0.2742 - mae_metric: 0.4163 - val_loss: 7.5395 - val_mae_metric: 2.6429
#
# Epoch 00005: val_loss did not improve from 0.56039
# Epoch 6/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.2446 - mae_metric: 0.3962 - val_loss: 9.1200 - val_mae_metric: 2.9267
#
# Epoch 00006: val_loss did not improve from 0.56039
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 7/200
# 55/55 [==============================] - 26s 466ms/step - loss: 0.2233 - mae_metric: 0.3651 - val_loss: 10.0330 - val_mae_metric: 3.0787
#
# Epoch 00007: val_loss did not improve from 0.56039
# Epoch 8/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.2019 - mae_metric: 0.3545 - val_loss: 7.4378 - val_mae_metric: 2.6236
#
# Epoch 00008: val_loss did not improve from 0.56039
# Epoch 9/200
# 55/55 [==============================] - 25s 464ms/step - loss: 0.1756 - mae_metric: 0.3376 - val_loss: 7.8091 - val_mae_metric: 2.6948
#
# Epoch 00009: val_loss did not improve from 0.56039
# Epoch 10/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.1757 - mae_metric: 0.3320 - val_loss: 5.8936 - val_mae_metric: 2.3185
#
# Epoch 00010: val_loss did not improve from 0.56039
# Epoch 11/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.1604 - mae_metric: 0.3166 - val_loss: 3.2459 - val_mae_metric: 1.7195
#
# Epoch 00011: val_loss did not improve from 0.56039
# Epoch 12/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.1430 - mae_metric: 0.3018 - val_loss: 0.8963 - val_mae_metric: 0.8128
#
# Epoch 00012: val_loss did not improve from 0.56039
# Epoch 13/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.1442 - mae_metric: 0.3034 - val_loss: 0.2209 - val_mae_metric: 0.3849
#
# Epoch 00013: val_loss improved from 0.56039 to 0.22088, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 14/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.1297 - mae_metric: 0.2922 - val_loss: 0.1928 - val_mae_metric: 0.3525
#
# Epoch 00014: val_loss improved from 0.22088 to 0.19277, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 15/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.1381 - mae_metric: 0.3001 - val_loss: 0.2100 - val_mae_metric: 0.3426
#
# Epoch 00015: val_loss did not improve from 0.19277
# Epoch 16/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.1295 - mae_metric: 0.2869 - val_loss: 0.6016 - val_mae_metric: 0.6894
#
# Epoch 00016: val_loss did not improve from 0.19277
# Epoch 17/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.1195 - mae_metric: 0.2728 - val_loss: 0.2986 - val_mae_metric: 0.4572
#
# Epoch 00017: val_loss did not improve from 0.19277
# Epoch 18/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.1070 - mae_metric: 0.2595 - val_loss: 0.2957 - val_mae_metric: 0.4356
#
# Epoch 00018: val_loss did not improve from 0.19277
# Epoch 19/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.1033 - mae_metric: 0.2506 - val_loss: 0.3326 - val_mae_metric: 0.4752
#
# Epoch 00019: val_loss did not improve from 0.19277
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 20/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0972 - mae_metric: 0.2494 - val_loss: 0.5039 - val_mae_metric: 0.6438
#
# Epoch 00020: val_loss did not improve from 0.19277
# Epoch 21/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0895 - mae_metric: 0.2326 - val_loss: 0.1312 - val_mae_metric: 0.2919
#
# Epoch 00021: val_loss improved from 0.19277 to 0.13122, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 22/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.1034 - mae_metric: 0.2511 - val_loss: 0.3886 - val_mae_metric: 0.5395
#
# Epoch 00022: val_loss did not improve from 0.13122
# Epoch 23/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0816 - mae_metric: 0.2271 - val_loss: 0.2135 - val_mae_metric: 0.3490
#
# Epoch 00023: val_loss did not improve from 0.13122
# Epoch 24/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0953 - mae_metric: 0.2528 - val_loss: 0.3775 - val_mae_metric: 0.5304
#
# Epoch 00024: val_loss did not improve from 0.13122
# Epoch 25/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0832 - mae_metric: 0.2271 - val_loss: 0.2998 - val_mae_metric: 0.4270
#
# Epoch 00025: val_loss did not improve from 0.13122
# Epoch 26/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0908 - mae_metric: 0.2426 - val_loss: 0.9954 - val_mae_metric: 0.9320
#
# Epoch 00026: val_loss did not improve from 0.13122
# Epoch 27/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0710 - mae_metric: 0.2126 - val_loss: 0.2594 - val_mae_metric: 0.4179
#
# Epoch 00027: val_loss did not improve from 0.13122
# Epoch 28/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0783 - mae_metric: 0.2210 - val_loss: 0.1085 - val_mae_metric: 0.2548
#
# Epoch 00028: val_loss improved from 0.13122 to 0.10853, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 29/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0720 - mae_metric: 0.2115 - val_loss: 0.2799 - val_mae_metric: 0.4547
#
# Epoch 00029: val_loss did not improve from 0.10853
# Epoch 30/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0636 - mae_metric: 0.2029 - val_loss: 0.7407 - val_mae_metric: 0.7882
#
# Epoch 00030: val_loss did not improve from 0.10853
# Epoch 31/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.0655 - mae_metric: 0.2037 - val_loss: 0.0863 - val_mae_metric: 0.2292
#
# Epoch 00031: val_loss improved from 0.10853 to 0.08627, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 32/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0773 - mae_metric: 0.2209 - val_loss: 0.1882 - val_mae_metric: 0.3631
#
# Epoch 00032: val_loss did not improve from 0.08627
# Epoch 33/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0813 - mae_metric: 0.2301 - val_loss: 0.3372 - val_mae_metric: 0.5067
#
# Epoch 00033: val_loss did not improve from 0.08627
# Epoch 34/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0631 - mae_metric: 0.1976 - val_loss: 0.1714 - val_mae_metric: 0.3229
#
# Epoch 00034: val_loss did not improve from 0.08627
# Epoch 35/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0865 - mae_metric: 0.2325 - val_loss: 0.1769 - val_mae_metric: 0.3500
#
# Epoch 00035: val_loss did not improve from 0.08627
# Epoch 36/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0562 - mae_metric: 0.1916 - val_loss: 0.1152 - val_mae_metric: 0.2657
#
# Epoch 00036: val_loss did not improve from 0.08627
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 37/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0640 - mae_metric: 0.1964 - val_loss: 0.1419 - val_mae_metric: 0.2953
#
# Epoch 00037: val_loss did not improve from 0.08627
# Epoch 38/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0637 - mae_metric: 0.2004 - val_loss: 0.3590 - val_mae_metric: 0.5386
# Epoch 00038: val_loss did not improve from 0.08627
# Epoch 39/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.0560 - mae_metric: 0.1895 - val_loss: 0.1186 - val_mae_metric: 0.2574
#
# Epoch 00039: val_loss did not improve from 0.08627
# Epoch 40/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0671 - mae_metric: 0.2150 - val_loss: 0.1020 - val_mae_metric: 0.2537
#
# Epoch 00040: val_loss did not improve from 0.08627
# Epoch 41/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0810 - mae_metric: 0.2363 - val_loss: 0.2463 - val_mae_metric: 0.4334
#
# Epoch 00041: val_loss did not improve from 0.08627
# Epoch 42/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0865 - mae_metric: 0.2349 - val_loss: 0.0939 - val_mae_metric: 0.2427
#
# Epoch 00042: val_loss did not improve from 0.08627
# Epoch 43/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0650 - mae_metric: 0.2036 - val_loss: 0.1217 - val_mae_metric: 0.2715
#
# Epoch 00043: val_loss did not improve from 0.08627
# Epoch 44/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.0592 - mae_metric: 0.1937 - val_loss: 0.2147 - val_mae_metric: 0.3574
#
# Epoch 00044: val_loss did not improve from 0.08627
# Epoch 45/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0729 - mae_metric: 0.2065 - val_loss: 0.0823 - val_mae_metric: 0.2225
#
# Epoch 00045: val_loss improved from 0.08627 to 0.08229, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 46/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0629 - mae_metric: 0.2028 - val_loss: 0.2639 - val_mae_metric: 0.4405
#
# Epoch 00046: val_loss did not improve from 0.08229
# Epoch 47/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0786 - mae_metric: 0.2184 - val_loss: 0.0903 - val_mae_metric: 0.2295
#
# Epoch 00047: val_loss did not improve from 0.08229
# Epoch 48/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0534 - mae_metric: 0.1804 - val_loss: 0.0814 - val_mae_metric: 0.2223
#
# Epoch 00048: val_loss improved from 0.08229 to 0.08135, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 49/200
# 55/55 [==============================] - 26s 466ms/step - loss: 0.0502 - mae_metric: 0.1808 - val_loss: 0.1199 - val_mae_metric: 0.2634
#
# Epoch 00049: val_loss did not improve from 0.08135
# Epoch 50/200
# 55/55 [==============================] - 26s 467ms/step - loss: 0.0573 - mae_metric: 0.1916 - val_loss: 0.1002 - val_mae_metric: 0.2458
#
# Epoch 00050: val_loss did not improve from 0.08135
# Epoch 51/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0577 - mae_metric: 0.1890 - val_loss: 0.1607 - val_mae_metric: 0.3397
#
# Epoch 00051: val_loss did not improve from 0.08135
# Epoch 52/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0601 - mae_metric: 0.1901 - val_loss: 0.1024 - val_mae_metric: 0.2345
#
# Epoch 00052: val_loss did not improve from 0.08135
# Epoch 53/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0523 - mae_metric: 0.1848 - val_loss: 0.1190 - val_mae_metric: 0.2655
#
# Epoch 00053: val_loss did not improve from 0.08135
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 54/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0490 - mae_metric: 0.1780 - val_loss: 0.0940 - val_mae_metric: 0.2391
#
# Epoch 00054: val_loss did not improve from 0.08135
# Epoch 55/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0399 - mae_metric: 0.1597 - val_loss: 0.2188 - val_mae_metric: 0.3981
#
# Epoch 00055: val_loss did not improve from 0.08135
# Epoch 56/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.0544 - mae_metric: 0.1843 - val_loss: 0.0738 - val_mae_metric: 0.1961
#
# Epoch 00056: val_loss improved from 0.08135 to 0.07380, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 57/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.0583 - mae_metric: 0.1965 - val_loss: 0.0775 - val_mae_metric: 0.2116
#
# Epoch 00057: val_loss did not improve from 0.07380
# Epoch 58/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0598 - mae_metric: 0.1974 - val_loss: 0.0725 - val_mae_metric: 0.1977
#
# Epoch 00058: val_loss improved from 0.07380 to 0.07250, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 59/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0570 - mae_metric: 0.1877 - val_loss: 0.1072 - val_mae_metric: 0.2397
#
# Epoch 00059: val_loss did not improve from 0.07250
# Epoch 60/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0548 - mae_metric: 0.1874 - val_loss: 0.0900 - val_mae_metric: 0.2228
#
# Epoch 00060: val_loss did not improve from 0.07250
# Epoch 61/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0528 - mae_metric: 0.1833 - val_loss: 0.0731 - val_mae_metric: 0.2175
#
# Epoch 00061: val_loss did not improve from 0.07250
# Epoch 62/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0489 - mae_metric: 0.1833 - val_loss: 0.0775 - val_mae_metric: 0.2074
#
# Epoch 00062: val_loss did not improve from 0.07250
# Epoch 63/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0450 - mae_metric: 0.1677 - val_loss: 0.1460 - val_mae_metric: 0.3149
#
# Epoch 00063: val_loss did not improve from 0.07250
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 64/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0578 - mae_metric: 0.1905 - val_loss: 0.0761 - val_mae_metric: 0.2056
#
# Epoch 00064: val_loss did not improve from 0.07250
# Epoch 65/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0520 - mae_metric: 0.1845 - val_loss: 0.0727 - val_mae_metric: 0.1980
#
# Epoch 00065: val_loss did not improve from 0.07250
# Epoch 66/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0492 - mae_metric: 0.1805 - val_loss: 0.0892 - val_mae_metric: 0.2320
#
# Epoch 00066: val_loss did not improve from 0.07250
# Epoch 67/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0473 - mae_metric: 0.1729 - val_loss: 0.0827 - val_mae_metric: 0.2276
#
# Epoch 00067: val_loss did not improve from 0.07250
# Epoch 68/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0524 - mae_metric: 0.1836 - val_loss: 0.0726 - val_mae_metric: 0.1967
#
# Epoch 00068: val_loss did not improve from 0.07250
# Epoch 69/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0597 - mae_metric: 0.1978 - val_loss: 0.0781 - val_mae_metric: 0.2050
#
# Epoch 00069: val_loss did not improve from 0.07250
# Epoch 70/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0490 - mae_metric: 0.1770 - val_loss: 0.0774 - val_mae_metric: 0.2082
#
# Epoch 00070: val_loss did not improve from 0.07250
# Epoch 71/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0557 - mae_metric: 0.1777 - val_loss: 0.0696 - val_mae_metric: 0.2009
#
# Epoch 00071: val_loss improved from 0.07250 to 0.06960, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 72/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0518 - mae_metric: 0.1837 - val_loss: 0.0809 - val_mae_metric: 0.2132
#
# Epoch 00072: val_loss did not improve from 0.06960
# Epoch 73/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0536 - mae_metric: 0.1867 - val_loss: 0.1298 - val_mae_metric: 0.2711
#
# Epoch 00073: val_loss did not improve from 0.06960
# Epoch 74/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0503 - mae_metric: 0.1792 - val_loss: 0.0689 - val_mae_metric: 0.1936
#
# Epoch 00074: val_loss improved from 0.06960 to 0.06889, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 75/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0545 - mae_metric: 0.1845 - val_loss: 0.0836 - val_mae_metric: 0.2292
#
# Epoch 00075: val_loss did not improve from 0.06889
# Epoch 76/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0516 - mae_metric: 0.1816 - val_loss: 0.0725 - val_mae_metric: 0.2000
# Epoch 00076: val_loss did not improve from 0.06889
# Epoch 77/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0476 - mae_metric: 0.1768 - val_loss: 0.1444 - val_mae_metric: 0.3065
#
# Epoch 00077: val_loss did not improve from 0.06889
# Epoch 78/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0661 - mae_metric: 0.2115 - val_loss: 0.0839 - val_mae_metric: 0.2404
#
# Epoch 00078: val_loss did not improve from 0.06889
# Epoch 79/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0502 - mae_metric: 0.1768 - val_loss: 0.0655 - val_mae_metric: 0.1862
#
# Epoch 00079: val_loss improved from 0.06889 to 0.06553, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 80/200
# 55/55 [==============================] - 26s 468ms/step - loss: 0.0447 - mae_metric: 0.1689 - val_loss: 0.0873 - val_mae_metric: 0.2324
#
# Epoch 00080: val_loss did not improve from 0.06553
# Epoch 81/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0646 - mae_metric: 0.2052 - val_loss: 0.0831 - val_mae_metric: 0.2281
#
# Epoch 00081: val_loss did not improve from 0.06553
# Epoch 82/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0437 - mae_metric: 0.1636 - val_loss: 0.0773 - val_mae_metric: 0.2098
#
# Epoch 00082: val_loss did not improve from 0.06553
# Epoch 83/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0489 - mae_metric: 0.1722 - val_loss: 0.1177 - val_mae_metric: 0.2823
#
# Epoch 00083: val_loss did not improve from 0.06553
# Epoch 84/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0469 - mae_metric: 0.1711 - val_loss: 0.0711 - val_mae_metric: 0.1996
#
# Epoch 00084: val_loss did not improve from 0.06553
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 85/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0604 - mae_metric: 0.1968 - val_loss: 0.0619 - val_mae_metric: 0.1817
#
# Epoch 00085: val_loss improved from 0.06553 to 0.06191, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 86/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0567 - mae_metric: 0.1948 - val_loss: 0.0649 - val_mae_metric: 0.1821
#
# Epoch 00086: val_loss did not improve from 0.06191
# Epoch 87/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0706 - mae_metric: 0.2119 - val_loss: 0.0636 - val_mae_metric: 0.1841
#
# Epoch 00087: val_loss did not improve from 0.06191
# Epoch 88/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0551 - mae_metric: 0.1888 - val_loss: 0.0729 - val_mae_metric: 0.2154
#
# Epoch 00088: val_loss did not improve from 0.06191
# Epoch 89/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0451 - mae_metric: 0.1690 - val_loss: 0.0676 - val_mae_metric: 0.1916
#
# Epoch 00089: val_loss did not improve from 0.06191
# Epoch 90/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0431 - mae_metric: 0.1625 - val_loss: 0.0723 - val_mae_metric: 0.2046
#
# Epoch 00090: val_loss did not improve from 0.06191
# Epoch 91/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0450 - mae_metric: 0.1646 - val_loss: 0.0759 - val_mae_metric: 0.2041
#
# Epoch 00091: val_loss did not improve from 0.06191
# Epoch 92/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0485 - mae_metric: 0.1750 - val_loss: 0.1104 - val_mae_metric: 0.2527
#
# Epoch 00092: val_loss did not improve from 0.06191
# Epoch 93/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0463 - mae_metric: 0.1704 - val_loss: 0.0659 - val_mae_metric: 0.1942
#
# Epoch 00093: val_loss did not improve from 0.06191
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 94/200
# 55/55 [==============================] - 26s 471ms/step - loss: 0.0417 - mae_metric: 0.1604 - val_loss: 0.0647 - val_mae_metric: 0.1849
#
# Epoch 00094: val_loss did not improve from 0.06191
# Epoch 95/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0491 - mae_metric: 0.1776 - val_loss: 0.0766 - val_mae_metric: 0.2026
#
# Epoch 00095: val_loss did not improve from 0.06191
# Epoch 96/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0494 - mae_metric: 0.1762 - val_loss: 0.0679 - val_mae_metric: 0.1925
#
# Epoch 00096: val_loss did not improve from 0.06191
# Epoch 97/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0581 - mae_metric: 0.1964 - val_loss: 0.0712 - val_mae_metric: 0.2006
#
# Epoch 00097: val_loss did not improve from 0.06191
# Epoch 98/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0537 - mae_metric: 0.1854 - val_loss: 0.0604 - val_mae_metric: 0.1800
#
# Epoch 00098: val_loss improved from 0.06191 to 0.06042, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 99/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0535 - mae_metric: 0.1914 - val_loss: 0.0655 - val_mae_metric: 0.1894
#
# Epoch 00099: val_loss did not improve from 0.06042
# Epoch 100/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0514 - mae_metric: 0.1775 - val_loss: 0.0614 - val_mae_metric: 0.1834
#
# Epoch 00100: val_loss did not improve from 0.06042
# Epoch 101/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0412 - mae_metric: 0.1636 - val_loss: 0.0679 - val_mae_metric: 0.2071
#
# Epoch 00101: val_loss did not improve from 0.06042
# Epoch 102/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0395 - mae_metric: 0.1606 - val_loss: 0.0683 - val_mae_metric: 0.2023
#
# Epoch 00102: val_loss did not improve from 0.06042
# Epoch 103/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0584 - mae_metric: 0.1940 - val_loss: 0.0864 - val_mae_metric: 0.2294
#
# Epoch 00103: val_loss did not improve from 0.06042
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 104/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0499 - mae_metric: 0.1775 - val_loss: 0.0614 - val_mae_metric: 0.1836
#
# Epoch 00104: val_loss did not improve from 0.06042
# Epoch 105/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0416 - mae_metric: 0.1654 - val_loss: 0.0660 - val_mae_metric: 0.1925
#
# Epoch 00105: val_loss did not improve from 0.06042
# Epoch 106/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0453 - mae_metric: 0.1700 - val_loss: 0.0663 - val_mae_metric: 0.1983
#
# Epoch 00106: val_loss did not improve from 0.06042
# Epoch 107/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0434 - mae_metric: 0.1598 - val_loss: 0.0626 - val_mae_metric: 0.1823
#
# Epoch 00107: val_loss did not improve from 0.06042
# Epoch 108/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0322 - mae_metric: 0.1443 - val_loss: 0.0634 - val_mae_metric: 0.1896
#
# Epoch 00108: val_loss did not improve from 0.06042
# Epoch 109/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0394 - mae_metric: 0.1567 - val_loss: 0.0646 - val_mae_metric: 0.1897
#
# Epoch 00109: val_loss did not improve from 0.06042
# Epoch 110/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0473 - mae_metric: 0.1677 - val_loss: 0.0647 - val_mae_metric: 0.1861
#
# Epoch 00110: val_loss did not improve from 0.06042
# Epoch 111/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0443 - mae_metric: 0.1661 - val_loss: 0.0666 - val_mae_metric: 0.1990
#
# Epoch 00111: val_loss did not improve from 0.06042
# Epoch 112/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0336 - mae_metric: 0.1478 - val_loss: 0.0658 - val_mae_metric: 0.1954
#
# Epoch 00112: val_loss did not improve from 0.06042
#
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 113/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0365 - mae_metric: 0.1494 - val_loss: 0.0643 - val_mae_metric: 0.1904
#
# Epoch 00113: val_loss did not improve from 0.06042
# Epoch 114/200
# 55/55 [==============================] - 26s 469ms/step - loss: 0.0557 - mae_metric: 0.1965 - val_loss: 0.0649 - val_mae_metric: 0.1921
#
# Epoch 00114: val_loss did not improve from 0.06042
# Epoch 115/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0500 - mae_metric: 0.1788 - val_loss: 0.0594 - val_mae_metric: 0.1788
#
# Epoch 00115: val_loss improved from 0.06042 to 0.05943, saving model to mcy_H_weights_trial4_13batch.best.nearshore.hdf5
# Epoch 116/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0449 - mae_metric: 0.1741 - val_loss: 0.0676 - val_mae_metric: 0.2002
#
# Epoch 00116: val_loss did not improve from 0.05943
# Epoch 117/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0465 - mae_metric: 0.1758 - val_loss: 0.0653 - val_mae_metric: 0.1884
#
# Epoch 00117: val_loss did not improve from 0.05943
# Epoch 118/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0441 - mae_metric: 0.1717 - val_loss: 0.0703 - val_mae_metric: 0.1940
#
# Epoch 00118: val_loss did not improve from 0.05943
# Epoch 119/200
# 55/55 [==============================] - 26s 470ms/step - loss: 0.0482 - mae_metric: 0.1790 - val_loss: 0.0632 - val_mae_metric: 0.1861
#
# Epoch 00119: val_loss did not improve from 0.05943
# Epoch 120/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0483 - mae_metric: 0.1720 - val_loss: 0.0689 - val_mae_metric: 0.1944
#
# Epoch 00120: val_loss did not improve from 0.05943
# Epoch 121/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0654 - mae_metric: 0.2046 - val_loss: 0.0699 - val_mae_metric: 0.1919
#
# Epoch 00121: val_loss did not improve from 0.05943
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 122/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0446 - mae_metric: 0.1734 - val_loss: 0.0635 - val_mae_metric: 0.1825
#
# Epoch 00122: val_loss did not improve from 0.05943
# Epoch 123/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0665 - mae_metric: 0.2133 - val_loss: 0.0603 - val_mae_metric: 0.1821
#
# Epoch 00123: val_loss did not improve from 0.05943
# Epoch 124/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0407 - mae_metric: 0.1613 - val_loss: 0.0642 - val_mae_metric: 0.1923
#
# Epoch 00124: val_loss did not improve from 0.05943
# Epoch 125/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0498 - mae_metric: 0.1807 - val_loss: 0.0656 - val_mae_metric: 0.1972
#
# Epoch 00125: val_loss did not improve from 0.05943
# Epoch 126/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0510 - mae_metric: 0.1833 - val_loss: 0.0654 - val_mae_metric: 0.1950
#
# Epoch 00126: val_loss did not improve from 0.05943
# Epoch 127/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0543 - mae_metric: 0.1906 - val_loss: 0.0661 - val_mae_metric: 0.1882
#
# Epoch 00127: val_loss did not improve from 0.05943
# Epoch 128/200
# 55/55 [==============================] - 26s 477ms/step - loss: 0.0422 - mae_metric: 0.1655 - val_loss: 0.0625 - val_mae_metric: 0.1889
#
# Epoch 00128: val_loss did not improve from 0.05943
# Epoch 129/200
# 55/55 [==============================] - 26s 479ms/step - loss: 0.0484 - mae_metric: 0.1853 - val_loss: 0.0607 - val_mae_metric: 0.1822
#
# Epoch 00129: val_loss did not improve from 0.05943
# Epoch 130/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0495 - mae_metric: 0.1764 - val_loss: 0.0605 - val_mae_metric: 0.1830
#
# Epoch 00130: val_loss did not improve from 0.05943
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 131/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0513 - mae_metric: 0.1840 - val_loss: 0.0647 - val_mae_metric: 0.1957
#
# Epoch 00131: val_loss did not improve from 0.05943
# Epoch 132/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0423 - mae_metric: 0.1672 - val_loss: 0.0627 - val_mae_metric: 0.1884
#
# Epoch 00132: val_loss did not improve from 0.05943
# Epoch 133/200
# 55/55 [==============================] - 26s 476ms/step - loss: 0.0691 - mae_metric: 0.2163 - val_loss: 0.0624 - val_mae_metric: 0.1850
#
# Epoch 00133: val_loss did not improve from 0.05943
# Epoch 134/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0539 - mae_metric: 0.1864 - val_loss: 0.0606 - val_mae_metric: 0.1813
#
# Epoch 00134: val_loss did not improve from 0.05943
# Epoch 135/200
# 55/55 [==============================] - 26s 475ms/step - loss: 0.0351 - mae_metric: 0.1505 - val_loss: 0.0606 - val_mae_metric: 0.1815
#
# Epoch 00135: val_loss did not improve from 0.05943
# Epoch 136/200
# 55/55 [==============================] - 26s 474ms/step - loss: 0.0439 - mae_metric: 0.1674 - val_loss: 0.0615 - val_mae_metric: 0.1807
#
# Epoch 00136: val_loss did not improve from 0.05943
# Epoch 137/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0348 - mae_metric: 0.1486 - val_loss: 0.0609 - val_mae_metric: 0.1818
#
# Epoch 00137: val_loss did not improve from 0.05943
# Epoch 138/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0560 - mae_metric: 0.1984 - val_loss: 0.0618 - val_mae_metric: 0.1836
#
# Epoch 00138: val_loss did not improve from 0.05943
# Epoch 139/200
# 55/55 [==============================] - 26s 472ms/step - loss: 0.0443 - mae_metric: 0.1746 - val_loss: 0.0608 - val_mae_metric: 0.1837
#
# Epoch 00139: val_loss did not improve from 0.05943
# Epoch 140/200
# 55/55 [==============================] - 26s 473ms/step - loss: 0.0428 - mae_metric: 0.1656 - val_loss: 0.0611 - val_mae_metric: 0.1828
#
# Epoch 00140: val_loss did not improve from 0.05943
# Wall time: 1h 31s

# %% [markdown]
# Make a plot showing training history

# %%
fig = plt.figure(figsize = (6,6))
plt.subplot(121)
# summarize history for accuracy
plt.plot(history.history['mae_metric'])
plt.plot(history.history['val_mae_metric'])
plt.ylabel('Mean absolute error')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(122)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# Make a plot showing predicted wave heights versus observed
#
# Use the model to estimate wave height from every image (that number can be anything from 1 to the length of `test_X`)

# %%
pred_Y = np.squeeze(OWG.predict(test_X, batch_size = batch_size, verbose = True))
# Out:
# 82/82 [==============================] - 5s 54ms/step

# %% [markdown]
# Make a plot of observed versus estimated wave height

# %%
print ("[INFO] Plotting ...")     												        
fig, ax1 = plt.subplots(1,1, figsize = (6,6))
ax1.plot(test_Y, pred_Y, 'b.', alpha=0.5, label = 'Estimated')
ax1.plot(test_Y, test_Y, 'k-', label = 'Observed')
ax1.legend()
if category=='H':
   ax1.set_xlabel('Actual H (m)')
   ax1.set_ylabel('Estimated H (m)')
else:
   ax1.set_xlabel('Actual T (s)')
   ax1.set_ylabel('Estimated T (s)')    
plt.show()
# Out:
# [INFO] Plotting ...

# %% [markdown]
# Show a few augmanted test images and their estimates wave height (and observed wave height, for comparison)

# %%
rand_idx = np.random.choice(range(test_X.shape[0]), 9)
fig, m_axs = plt.subplots(3, 3, figsize = (16, 16))
for (idx, c_ax) in zip(rand_idx, m_axs.flatten()):
  c_ax.imshow(test_X[idx, :,:,0], cmap = 'gray')
  if category == 'H':
      c_ax.set_title('H: %0.3f\nPredicted H: %0.3f' % (test_Y[idx], pred_Y[idx]))
  else:
      c_ax.set_title('T: %0.3f\nPredicted T: %0.3f' % (test_Y[idx], pred_Y[idx]))
  
  c_ax.axis('off')

# %%
#r^2 value

from scipy.stats import linregress

def rsquared(x, y):
    """ Return R^2 where x and y are array-like."""

    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    return r_value**2

# %%
r_value = rsquared(test_Y, pred_Y)
# round r^2 to the number of decimal places that is present in the OWG_train mean absolute error
print (round(r_value, 5))
# Out:
# 0.89402

# %%
def mape(actual, pred): 
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
errorper = mape(test_Y, pred_Y)
print (errorper)
# Out:
# 28.694133444029426
