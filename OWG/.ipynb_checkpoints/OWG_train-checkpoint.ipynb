# %% [markdown]
# # Optical Wave Gauging for Google Colab
#
# by Daniel Buscombe, daniel.buscombe@nau.edu
#
# This notebook is part of https://github.com/dbuscombe-usgs/OpticalWaveGauging_DNN
#
# ### Train an optical wave gage (OWG) to estimate wave height from an image
#
#
# First, enable a GPU runtime:
#
# In Colab, go to runtime > change runtime type > hardware accelerator: GPU
#
#
# Workflow:
#
# 1. Write a configuration file - this is how you interact with OWG functions
# 2. Download the data and model weights
# 3. Define the model
# 4. Generate test images and associated wave heights from the downloaded imagery
# 5. Use the model to estimate wave height for each image
# 6. Make plots

# %% [markdown]
# Import libraries

# %%
import numpy as np 
import pandas as pd 
import os, gc, requests, zipfile
import time, datetime, json
from glob import glob
from sklearn.model_selection import train_test_split

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# This notebook assumes you are in Google Colab. Therefore, switch to Tensorflow 2 and verify by printing the version, which should say '2.X.X' where X can be any number

# %%
#%tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import mean_absolute_error
# Out:
# 2.5.0

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# Write the configuration file using the magic command 'writefile'

# %%
# %%writefile config_trainMC17validation.json
# {
#   "samplewise_std_normalization" : true,
#   "samplewise_center"  : true,
#   "input_image_format" : "jpg",
#   "input_csv_file"     : "mcyv22017(validationtrain).csv",
#   "category"           : "H",
#   "prc_lower_withheld": 0,
#   "prc_upper_withheld": 0,
#
#   "horizontal_flip"    : false,
#   "vertical_flip"      : false,
#   "rotation_range"     : 10,
#   "width_shift_range"  : 0.1,
#   "height_shift_range" : 0.1,
#   "shear_range"        : 0.05,
#   "zoom_range"         : 0.2,
#   "fill_mode"          : "reflect",
#
#   "img_size"           : 256,
#   "num_epochs"         : 200,
#   "test_size"          : 0.4,
#   "dropout_rate"       : 0.5,
#   "epsilon"            : 0.0001,
#   "min_lr"             : 0.0001,
#   "factor"             : 0.8
# }
# Out:
# Overwriting config_trainMC17validation.json

# %% [markdown]
# Open the config file and read values into workspace. This might seem like a long-winded way of doing things -- and it is --- but this is how things are set up in the command line python scripts version of this workflow in `https://github.com/dbuscombe-usgs/OpticalWaveGauging_DNN/train_OWG.py` so it is maintained here for consistency

# %%
with open('config_trainMC17validation.json') as f:    
    config = json.load(f)

# config variables
imsize    = int(config["img_size"])
num_epochs = int(config["num_epochs"]) 
test_size = float(config["test_size"])
height_shift_range = float(config["height_shift_range"])
width_shift_range = float(config["width_shift_range"])
rotation_range = float(config["rotation_range"])
samplewise_std_normalization = config["samplewise_std_normalization"]
horizontal_flip = config["horizontal_flip"]
vertical_flip = config["vertical_flip"]
samplewise_center = config["samplewise_center"]
shear_range = float(config["shear_range"])
zoom_range = float(config["zoom_range"])
dropout_rate = float(config["dropout_rate"])
epsilon = float(config["epsilon"])
min_lr = float(config["min_lr"])
factor = float(config["factor"])
input_image_format = config["input_image_format"]
input_csv_file = config["input_csv_file"]
category = config["category"] 
fill_mode = config["fill_mode"]
prc_lower_withheld = config['prc_lower_withheld'] 
prc_upper_withheld = config['prc_upper_withheld']
IMG_SIZE = (imsize, imsize)

# %%
image_dir = "C:/njc/src/mcyimgs/2017_imgprep1/owgtrainimgs"

# %%
def get_and_tidy_df(base_dir, input_csv_file, image_dir, category):
        df = pd.read_csv(os.path.join(base_dir, input_csv_file))
        df['path'] = df['id'].map(lambda x: os.path.join(base_dir,image_dir,'{}'.format(x)))
            
        df = df.rename(index=str, columns={" H": "H", " T": "T"})   
        
        if category == 'H':
            mean = df['H'].mean() 
            div = df['H'].std() 
            df['zscore'] = df['H'].map(lambda x: (x-mean)/div)
        elif category == 'T':
            mean = df['T'].mean() 
            div = df['T'].std() 
            df['zscore'] = df['T'].map(lambda x: (x-mean)/div)			
        else:
            print("Unknown category: "+str(category))
            print("Fix config file, exiting now ...")
            sys.exit()
        
        df.dropna(inplace = True)
        try:
            df = df.sort_values(by='time', axis=0)
        except:
            df = df.sort_values(by='id', axis=0)

        if category == 'H':
            df['category'] = pd.cut(df['H'], 10)
        else:
            df['category'] = pd.cut(df['T'], 8)
            
        df['index1'] = df.index; new_df = df.groupby(['category']).apply(lambda x: x.sample(int(len(df)/2), replace = True)).reset_index(drop = True)

        return new_df, df

# %% [markdown]
# Get a dataframe to generate test and train data from

# %%
# call the utils.py function get_and_tidy_df            	
new_df, df = get_and_tidy_df(os.getcwd(), input_csv_file, image_dir, category)

# %% [markdown]
# Get train and test splits and define the generator function that will do the image augmentation

# %%
print('New Data Size:', new_df.shape[0], 'Old Size:', df.shape[0])
      
train_df, valid_df = train_test_split(new_df, 
                    test_size = test_size, 
                    random_state = 2018,
                    stratify = new_df['category'])
print('train', train_df.shape[0], 'validation', valid_df.shape[0])

im_gen = ImageDataGenerator(samplewise_center=samplewise_center,
                samplewise_std_normalization=samplewise_std_normalization,
                horizontal_flip = horizontal_flip,  
                vertical_flip = vertical_flip, 
                height_shift_range = height_shift_range, 
                width_shift_range = width_shift_range, 
                rotation_range = rotation_range,
                shear_range = shear_range, 
                fill_mode = fill_mode,
                zoom_range= zoom_range)
# Out:
# New Data Size: 2870 Old Size: 574
# train 1722 validation 1148

# %% [markdown]
# Make a generator from a dataframe

# %%
def gen_from_def(IMG_SIZE, df, image_dir, category, im_gen):

	gen = im_gen.flow_from_dataframe(dataframe=df,
								  directory=image_dir,
								  x_col="path",
								  y_col=category,
								  target_size=IMG_SIZE,
								  batch_size=len(df),
								  color_mode = 'grayscale',
								  shuffle=False,
								  class_mode='raw')
								  	
	ex_X, ex_Y = next(gen)
	return ex_X, ex_Y

# %% [markdown]
# Get the train and test images and associated wave heights. This takes a while

# %%
train_X, train_Y = gen_from_def(IMG_SIZE, train_df, image_dir, category, im_gen)
test_X, test_Y = gen_from_def(IMG_SIZE, valid_df, image_dir, category, im_gen)
# Out:
# Found 1722 validated image filenames.
# Found 1148 validated image filenames.

# %%
batch_size = 16

weights_path='mcy_H_weights_modelvalidation_'+str(batch_size)+'batch.best.nearshore.hdf5'	
      
print(weights_path)
# Out:
# mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5

# %% [markdown]
# Create a model checkpoint, and training utilities such as early stopping, and reduce learning rate on a plateau in validaion loss

# %%
model_checkpoint = ModelCheckpoint(weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only = True)

reduceloss_plat = ReduceLROnPlateau(monitor='val_loss', factor=factor, patience=5, verbose=1, mode='auto', epsilon=epsilon, cooldown=5, min_lr=min_lr)
earlystop = EarlyStopping(monitor="val_loss", mode="min", patience=25) 
callbacks_list = [model_checkpoint, earlystop, reduceloss_plat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
# mean absolute error
def mae_metric(in_gt, in_pred):
    return mean_absolute_error(in_gt, in_pred)

# %% [markdown]
# Set model and print a summary

# %%
base_model = MobileNet(input_shape =  (IMG_SIZE[0], IMG_SIZE[1],1), include_top = False, weights = None)			
OWG = Sequential()
OWG.add(BatchNormalization(input_shape = (IMG_SIZE[0], IMG_SIZE[1],1)))
OWG.add(base_model)
OWG.add(BatchNormalization())
OWG.add(GlobalAveragePooling2D())
OWG.add(Dropout(0.5)) 
OWG.add(Dense(1, activation = 'linear' )) 

OWG.compile(optimizer = 'rmsprop', loss = 'mse', metrics = [mae_metric])
OWG.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 256, 256, 1)       4
# _________________________________________________________________
# mobilenet_1.00_256 (Function (None, 8, 8, 1024)        3228288
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 1024)        4096
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# Total params: 3,233,413
# Trainable params: 3,209,475
# Non-trainable params: 23,938
# _________________________________________________________________

# %%
# %%time
history = OWG.fit(train_X, train_Y, batch_size=batch_size, 
                  validation_data = (test_X, test_Y),
                  epochs=num_epochs, callbacks = callbacks_list)

OWG.load_weights(weights_path)
# Out:
# Epoch 1/200
# 108/108 [==============================] - 24s 159ms/step - loss: 1.5656 - mae_metric: 0.8181 - val_loss: 0.7666 - val_mae_metric: 0.7321
#
# Epoch 00001: val_loss improved from inf to 0.76657, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 2/200
# 108/108 [==============================] - 16s 147ms/step - loss: 0.5009 - mae_metric: 0.5707 - val_loss: 2.3859 - val_mae_metric: 1.3439
#
# Epoch 00002: val_loss did not improve from 0.76657
# Epoch 3/200
# 108/108 [==============================] - 16s 148ms/step - loss: 0.3922 - mae_metric: 0.5071 - val_loss: 1.2080 - val_mae_metric: 0.8990
#
# Epoch 00003: val_loss did not improve from 0.76657
# Epoch 4/200
# 108/108 [==============================] - 16s 148ms/step - loss: 0.3297 - mae_metric: 0.4573 - val_loss: 1.1818 - val_mae_metric: 0.8892
#
# Epoch 00004: val_loss did not improve from 0.76657
# Epoch 5/200
# 108/108 [==============================] - 16s 149ms/step - loss: 0.2837 - mae_metric: 0.4239 - val_loss: 1.5764 - val_mae_metric: 1.0430
#
# Epoch 00005: val_loss did not improve from 0.76657
# Epoch 6/200
# 108/108 [==============================] - 16s 149ms/step - loss: 0.2340 - mae_metric: 0.3868 - val_loss: 0.4447 - val_mae_metric: 0.5328
#
# Epoch 00006: val_loss improved from 0.76657 to 0.44469, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 7/200
# 108/108 [==============================] - 16s 149ms/step - loss: 0.2073 - mae_metric: 0.3638 - val_loss: 0.2769 - val_mae_metric: 0.4167
#
# Epoch 00007: val_loss improved from 0.44469 to 0.27692, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 8/200
# 108/108 [==============================] - 16s 150ms/step - loss: 0.1698 - mae_metric: 0.3231 - val_loss: 0.3485 - val_mae_metric: 0.4703
#
# Epoch 00008: val_loss did not improve from 0.27692
# Epoch 9/200
# 108/108 [==============================] - 16s 149ms/step - loss: 0.1538 - mae_metric: 0.3111 - val_loss: 1.7291 - val_mae_metric: 1.1433
#
# Epoch 00009: val_loss did not improve from 0.27692
# Epoch 10/200
# 108/108 [==============================] - 16s 150ms/step - loss: 0.1414 - mae_metric: 0.2942 - val_loss: 0.3011 - val_mae_metric: 0.4615
#
# Epoch 00010: val_loss did not improve from 0.27692
# Epoch 11/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.1202 - mae_metric: 0.2706 - val_loss: 0.6293 - val_mae_metric: 0.6692
#
# Epoch 00011: val_loss did not improve from 0.27692
# Epoch 12/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.1142 - mae_metric: 0.2719 - val_loss: 0.2932 - val_mae_metric: 0.4428
#
# Epoch 00012: val_loss did not improve from 0.27692
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 13/200
# 108/108 [==============================] - 16s 149ms/step - loss: 0.0986 - mae_metric: 0.2485 - val_loss: 0.2860 - val_mae_metric: 0.4538
#
# Epoch 00013: val_loss did not improve from 0.27692
# Epoch 14/200
# 108/108 [==============================] - 16s 150ms/step - loss: 0.0861 - mae_metric: 0.2314 - val_loss: 0.2097 - val_mae_metric: 0.3786
#
# Epoch 00014: val_loss improved from 0.27692 to 0.20972, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 15/200
# 108/108 [==============================] - 17s 156ms/step - loss: 0.0919 - mae_metric: 0.2409 - val_loss: 0.1020 - val_mae_metric: 0.2421
#
# Epoch 00015: val_loss improved from 0.20972 to 0.10196, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 16/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0789 - mae_metric: 0.2236 - val_loss: 0.1342 - val_mae_metric: 0.2926
#
# Epoch 00016: val_loss did not improve from 0.10196
# Epoch 17/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0676 - mae_metric: 0.2040 - val_loss: 0.0926 - val_mae_metric: 0.2326
#
# Epoch 00017: val_loss improved from 0.10196 to 0.09261, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 18/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0791 - mae_metric: 0.2244 - val_loss: 0.1436 - val_mae_metric: 0.2937
#
# Epoch 00018: val_loss did not improve from 0.09261
# Epoch 19/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0666 - mae_metric: 0.2029 - val_loss: 0.1078 - val_mae_metric: 0.2479
#
# Epoch 00019: val_loss did not improve from 0.09261
# Epoch 20/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0717 - mae_metric: 0.2165 - val_loss: 0.1191 - val_mae_metric: 0.2705
#
# Epoch 00020: val_loss did not improve from 0.09261
# Epoch 21/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0736 - mae_metric: 0.2151 - val_loss: 0.1277 - val_mae_metric: 0.2726
#
# Epoch 00021: val_loss did not improve from 0.09261
# Epoch 22/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0556 - mae_metric: 0.1865 - val_loss: 0.1104 - val_mae_metric: 0.2527
#
# Epoch 00022: val_loss did not improve from 0.09261
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 23/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0655 - mae_metric: 0.2027 - val_loss: 0.1050 - val_mae_metric: 0.2623
#
# Epoch 00023: val_loss did not improve from 0.09261
# Epoch 24/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0702 - mae_metric: 0.2142 - val_loss: 0.1103 - val_mae_metric: 0.2593
#
# Epoch 00024: val_loss did not improve from 0.09261
# Epoch 25/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0532 - mae_metric: 0.1846 - val_loss: 0.0815 - val_mae_metric: 0.2126
#
# Epoch 00025: val_loss improved from 0.09261 to 0.08151, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 26/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0589 - mae_metric: 0.1920 - val_loss: 0.1169 - val_mae_metric: 0.2468
#
# Epoch 00026: val_loss did not improve from 0.08151
# Epoch 27/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0567 - mae_metric: 0.1920 - val_loss: 0.0938 - val_mae_metric: 0.2239
#
# Epoch 00027: val_loss did not improve from 0.08151
# Epoch 28/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0527 - mae_metric: 0.1828 - val_loss: 0.0868 - val_mae_metric: 0.2242
#
# Epoch 00028: val_loss did not improve from 0.08151
# Epoch 29/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0571 - mae_metric: 0.1940 - val_loss: 0.0761 - val_mae_metric: 0.2137
#
# Epoch 00029: val_loss improved from 0.08151 to 0.07606, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 30/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0659 - mae_metric: 0.2062 - val_loss: 0.0705 - val_mae_metric: 0.1965
#
# Epoch 00030: val_loss improved from 0.07606 to 0.07046, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 31/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0579 - mae_metric: 0.1893 - val_loss: 0.1066 - val_mae_metric: 0.2472
#
# Epoch 00031: val_loss did not improve from 0.07046
# Epoch 32/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0550 - mae_metric: 0.1864 - val_loss: 0.0755 - val_mae_metric: 0.2043
#
# Epoch 00032: val_loss did not improve from 0.07046
# Epoch 33/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0587 - mae_metric: 0.1948 - val_loss: 0.0722 - val_mae_metric: 0.1993
#
# Epoch 00033: val_loss did not improve from 0.07046
# Epoch 34/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0582 - mae_metric: 0.1924 - val_loss: 0.0905 - val_mae_metric: 0.2368
#
# Epoch 00034: val_loss did not improve from 0.07046
# Epoch 35/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0576 - mae_metric: 0.1915 - val_loss: 0.0766 - val_mae_metric: 0.2092
#
# Epoch 00035: val_loss did not improve from 0.07046
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 36/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0521 - mae_metric: 0.1835 - val_loss: 0.0581 - val_mae_metric: 0.1782
# Epoch 00036: val_loss improved from 0.07046 to 0.05805, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 37/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0567 - mae_metric: 0.1872 - val_loss: 0.0729 - val_mae_metric: 0.2020
#
# Epoch 00037: val_loss did not improve from 0.05805
# Epoch 38/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0574 - mae_metric: 0.1934 - val_loss: 0.0584 - val_mae_metric: 0.1731
#
# Epoch 00038: val_loss did not improve from 0.05805
# Epoch 39/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0488 - mae_metric: 0.1782 - val_loss: 0.0681 - val_mae_metric: 0.1968
#
# Epoch 00039: val_loss did not improve from 0.05805
# Epoch 40/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0484 - mae_metric: 0.1706 - val_loss: 0.0631 - val_mae_metric: 0.1832
#
# Epoch 00040: val_loss did not improve from 0.05805
# Epoch 41/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0462 - mae_metric: 0.1694 - val_loss: 0.0812 - val_mae_metric: 0.2011
#
# Epoch 00041: val_loss did not improve from 0.05805
# Epoch 42/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0530 - mae_metric: 0.1824 - val_loss: 0.0669 - val_mae_metric: 0.1953
#
# Epoch 00042: val_loss did not improve from 0.05805
# Epoch 43/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0409 - mae_metric: 0.1593 - val_loss: 0.0560 - val_mae_metric: 0.1760
#
# Epoch 00043: val_loss improved from 0.05805 to 0.05603, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 44/200
# 108/108 [==============================] - 17s 155ms/step - loss: 0.0493 - mae_metric: 0.1771 - val_loss: 0.1327 - val_mae_metric: 0.3088
#
# Epoch 00044: val_loss did not improve from 0.05603
# Epoch 45/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0486 - mae_metric: 0.1755 - val_loss: 0.0653 - val_mae_metric: 0.2024
#
# Epoch 00045: val_loss did not improve from 0.05603
# Epoch 46/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0479 - mae_metric: 0.1739 - val_loss: 0.0570 - val_mae_metric: 0.1717
#
# Epoch 00046: val_loss did not improve from 0.05603
# Epoch 47/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0526 - mae_metric: 0.1815 - val_loss: 0.0552 - val_mae_metric: 0.1673
#
# Epoch 00047: val_loss improved from 0.05603 to 0.05520, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 48/200
# 108/108 [==============================] - 17s 155ms/step - loss: 0.0478 - mae_metric: 0.1710 - val_loss: 0.0530 - val_mae_metric: 0.1615
#
# Epoch 00048: val_loss improved from 0.05520 to 0.05296, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 49/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0478 - mae_metric: 0.1728 - val_loss: 0.0711 - val_mae_metric: 0.1924
#
# Epoch 00049: val_loss did not improve from 0.05296
# Epoch 50/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0479 - mae_metric: 0.1754 - val_loss: 0.0644 - val_mae_metric: 0.1815
#
# Epoch 00050: val_loss did not improve from 0.05296
# Epoch 51/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0495 - mae_metric: 0.1758 - val_loss: 0.0797 - val_mae_metric: 0.2078
#
# Epoch 00051: val_loss did not improve from 0.05296
# Epoch 52/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0416 - mae_metric: 0.1666 - val_loss: 0.0641 - val_mae_metric: 0.1787
#
# Epoch 00052: val_loss did not improve from 0.05296
# Epoch 53/200
# 108/108 [==============================] - 17s 156ms/step - loss: 0.0504 - mae_metric: 0.1794 - val_loss: 0.0661 - val_mae_metric: 0.2007
#
# Epoch 00053: val_loss did not improve from 0.05296
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 54/200
# 108/108 [==============================] - 17s 156ms/step - loss: 0.0450 - mae_metric: 0.1699 - val_loss: 0.0898 - val_mae_metric: 0.2244
#
# Epoch 00054: val_loss did not improve from 0.05296
# Epoch 55/200
# 108/108 [==============================] - 17s 156ms/step - loss: 0.0543 - mae_metric: 0.1814 - val_loss: 0.0556 - val_mae_metric: 0.1708
#
# Epoch 00055: val_loss did not improve from 0.05296
# Epoch 56/200
# 108/108 [==============================] - 17s 155ms/step - loss: 0.0473 - mae_metric: 0.1735 - val_loss: 0.0551 - val_mae_metric: 0.1707
#
# Epoch 00056: val_loss did not improve from 0.05296
# Epoch 57/200
# 108/108 [==============================] - 17s 155ms/step - loss: 0.0421 - mae_metric: 0.1628 - val_loss: 0.0553 - val_mae_metric: 0.1777
#
# Epoch 00057: val_loss did not improve from 0.05296
# Epoch 58/200
# 108/108 [==============================] - 17s 156ms/step - loss: 0.0478 - mae_metric: 0.1740 - val_loss: 0.0495 - val_mae_metric: 0.1599
#
# Epoch 00058: val_loss improved from 0.05296 to 0.04953, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 59/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0436 - mae_metric: 0.1660 - val_loss: 0.0498 - val_mae_metric: 0.1602
#
# Epoch 00059: val_loss did not improve from 0.04953
# Epoch 60/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0474 - mae_metric: 0.1716 - val_loss: 0.0496 - val_mae_metric: 0.1604
#
# Epoch 00060: val_loss did not improve from 0.04953
# Epoch 61/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0405 - mae_metric: 0.1580 - val_loss: 0.0519 - val_mae_metric: 0.1622
#
# Epoch 00061: val_loss did not improve from 0.04953
# Epoch 62/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0549 - mae_metric: 0.1909 - val_loss: 0.0564 - val_mae_metric: 0.1728
#
# Epoch 00062: val_loss did not improve from 0.04953
# Epoch 63/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0525 - mae_metric: 0.1868 - val_loss: 0.0620 - val_mae_metric: 0.1829
#
# Epoch 00063: val_loss did not improve from 0.04953
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 64/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0434 - mae_metric: 0.1675 - val_loss: 0.0531 - val_mae_metric: 0.1654
#
# Epoch 00064: val_loss did not improve from 0.04953
# Epoch 65/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0518 - mae_metric: 0.1813 - val_loss: 0.0496 - val_mae_metric: 0.1661
#
# Epoch 00065: val_loss did not improve from 0.04953
# Epoch 66/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0406 - mae_metric: 0.1584 - val_loss: 0.0645 - val_mae_metric: 0.2046
#
# Epoch 00066: val_loss did not improve from 0.04953
# Epoch 67/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0400 - mae_metric: 0.1578 - val_loss: 0.0540 - val_mae_metric: 0.1645
#
# Epoch 00067: val_loss did not improve from 0.04953
# Epoch 68/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0412 - mae_metric: 0.1620 - val_loss: 0.0520 - val_mae_metric: 0.1716
#
# Epoch 00068: val_loss did not improve from 0.04953
# Epoch 69/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0483 - mae_metric: 0.1749 - val_loss: 0.0524 - val_mae_metric: 0.1723
#
# Epoch 00069: val_loss did not improve from 0.04953
# Epoch 70/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0373 - mae_metric: 0.1555 - val_loss: 0.0505 - val_mae_metric: 0.1632
#
# Epoch 00070: val_loss did not improve from 0.04953
# Epoch 71/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0446 - mae_metric: 0.1658 - val_loss: 0.0547 - val_mae_metric: 0.1677
#
# Epoch 00071: val_loss did not improve from 0.04953
# Epoch 72/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0481 - mae_metric: 0.1736 - val_loss: 0.0543 - val_mae_metric: 0.1723
#
# Epoch 00072: val_loss did not improve from 0.04953
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 73/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0406 - mae_metric: 0.1653 - val_loss: 0.0507 - val_mae_metric: 0.1627
#
# Epoch 00073: val_loss did not improve from 0.04953
# Epoch 74/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0445 - mae_metric: 0.1713 - val_loss: 0.0539 - val_mae_metric: 0.1639
#
# Epoch 00074: val_loss did not improve from 0.04953
# Epoch 75/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0497 - mae_metric: 0.1765 - val_loss: 0.0494 - val_mae_metric: 0.1573
#
# Epoch 00075: val_loss improved from 0.04953 to 0.04940, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 76/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0485 - mae_metric: 0.1800 - val_loss: 0.0614 - val_mae_metric: 0.1910
#
# Epoch 00076: val_loss did not improve from 0.04940
# Epoch 77/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0460 - mae_metric: 0.1761 - val_loss: 0.0524 - val_mae_metric: 0.1698
#
# Epoch 00077: val_loss did not improve from 0.04940
# Epoch 78/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0424 - mae_metric: 0.1605 - val_loss: 0.0509 - val_mae_metric: 0.1589
#
# Epoch 00078: val_loss did not improve from 0.04940
# Epoch 79/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0406 - mae_metric: 0.1605 - val_loss: 0.0492 - val_mae_metric: 0.1583
#
# Epoch 00079: val_loss improved from 0.04940 to 0.04915, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 80/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0461 - mae_metric: 0.1745 - val_loss: 0.0573 - val_mae_metric: 0.1847
#
# Epoch 00080: val_loss did not improve from 0.04915
# Epoch 81/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0449 - mae_metric: 0.1689 - val_loss: 0.0527 - val_mae_metric: 0.1682
#
# Epoch 00081: val_loss did not improve from 0.04915
# Epoch 82/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0415 - mae_metric: 0.1611 - val_loss: 0.0514 - val_mae_metric: 0.1690
#
# Epoch 00082: val_loss did not improve from 0.04915
# Epoch 83/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0408 - mae_metric: 0.1635 - val_loss: 0.0511 - val_mae_metric: 0.1576
#
# Epoch 00083: val_loss did not improve from 0.04915
# Epoch 84/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0483 - mae_metric: 0.1754 - val_loss: 0.0482 - val_mae_metric: 0.1639
#
# Epoch 00084: val_loss improved from 0.04915 to 0.04815, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 85/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0499 - mae_metric: 0.1807 - val_loss: 0.0567 - val_mae_metric: 0.1870
#
# Epoch 00085: val_loss did not improve from 0.04815
# Epoch 86/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0368 - mae_metric: 0.1542 - val_loss: 0.0539 - val_mae_metric: 0.1607
#
# Epoch 00086: val_loss did not improve from 0.04815
# Epoch 87/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0454 - mae_metric: 0.1766 - val_loss: 0.0493 - val_mae_metric: 0.1588
#
# Epoch 00087: val_loss did not improve from 0.04815
# Epoch 88/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0431 - mae_metric: 0.1639 - val_loss: 0.0715 - val_mae_metric: 0.2150
#
# Epoch 00088: val_loss did not improve from 0.04815
# Epoch 89/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0421 - mae_metric: 0.1644 - val_loss: 0.0485 - val_mae_metric: 0.1559
#
# Epoch 00089: val_loss did not improve from 0.04815
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 90/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0441 - mae_metric: 0.1698 - val_loss: 0.0478 - val_mae_metric: 0.1566
#
# Epoch 00090: val_loss improved from 0.04815 to 0.04778, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 91/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0471 - mae_metric: 0.1705 - val_loss: 0.0496 - val_mae_metric: 0.1552
#
# Epoch 00091: val_loss did not improve from 0.04778
# Epoch 92/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0416 - mae_metric: 0.1654 - val_loss: 0.0487 - val_mae_metric: 0.1611
#
# Epoch 00092: val_loss did not improve from 0.04778
# Epoch 93/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0462 - mae_metric: 0.1681 - val_loss: 0.0507 - val_mae_metric: 0.1678
#
# Epoch 00093: val_loss did not improve from 0.04778
# Epoch 94/200
# 108/108 [==============================] - 16s 150ms/step - loss: 0.0407 - mae_metric: 0.1653 - val_loss: 0.0489 - val_mae_metric: 0.1572
#
# Epoch 00094: val_loss did not improve from 0.04778
# Epoch 95/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0484 - mae_metric: 0.1812 - val_loss: 0.0488 - val_mae_metric: 0.1540
#
# Epoch 00095: val_loss did not improve from 0.04778
# Epoch 96/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0381 - mae_metric: 0.1556 - val_loss: 0.0475 - val_mae_metric: 0.1512
#
# Epoch 00096: val_loss improved from 0.04778 to 0.04754, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 97/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0500 - mae_metric: 0.1818 - val_loss: 0.0521 - val_mae_metric: 0.1568
#
# Epoch 00097: val_loss did not improve from 0.04754
# Epoch 98/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0422 - mae_metric: 0.1654 - val_loss: 0.0508 - val_mae_metric: 0.1682
#
# Epoch 00098: val_loss did not improve from 0.04754
# Epoch 99/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0441 - mae_metric: 0.1690 - val_loss: 0.0534 - val_mae_metric: 0.1697
#
# Epoch 00099: val_loss did not improve from 0.04754
# Epoch 100/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0414 - mae_metric: 0.1630 - val_loss: 0.0462 - val_mae_metric: 0.1500
#
# Epoch 00100: val_loss improved from 0.04754 to 0.04623, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 101/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0500 - mae_metric: 0.1795 - val_loss: 0.0509 - val_mae_metric: 0.1669
#
# Epoch 00101: val_loss did not improve from 0.04623
# Epoch 102/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0397 - mae_metric: 0.1599 - val_loss: 0.0594 - val_mae_metric: 0.1954
#
# Epoch 00102: val_loss did not improve from 0.04623
# Epoch 103/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0442 - mae_metric: 0.1690 - val_loss: 0.0459 - val_mae_metric: 0.1502
#
# Epoch 00103: val_loss improved from 0.04623 to 0.04585, saving model to mcy_H_weights_modelvalidation_16batch.best.nearshore.hdf5
# Epoch 104/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0356 - mae_metric: 0.1538 - val_loss: 0.0513 - val_mae_metric: 0.1563
#
# Epoch 00104: val_loss did not improve from 0.04585
# Epoch 105/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0421 - mae_metric: 0.1600 - val_loss: 0.0502 - val_mae_metric: 0.1609
#
# Epoch 00105: val_loss did not improve from 0.04585
# Epoch 106/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0380 - mae_metric: 0.1546 - val_loss: 0.0494 - val_mae_metric: 0.1560
#
# Epoch 00106: val_loss did not improve from 0.04585
# Epoch 107/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0448 - mae_metric: 0.1726 - val_loss: 0.0487 - val_mae_metric: 0.1519
#
# Epoch 00107: val_loss did not improve from 0.04585
# Epoch 108/200
# 108/108 [==============================] - 16s 151ms/step - loss: 0.0473 - mae_metric: 0.1679 - val_loss: 0.0504 - val_mae_metric: 0.1666
#
# Epoch 00108: val_loss did not improve from 0.04585
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 109/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0350 - mae_metric: 0.1462 - val_loss: 0.0517 - val_mae_metric: 0.1580
#
# Epoch 00109: val_loss did not improve from 0.04585
# Epoch 110/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0431 - mae_metric: 0.1651 - val_loss: 0.0480 - val_mae_metric: 0.1517
#
# Epoch 00110: val_loss did not improve from 0.04585
# Epoch 111/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0330 - mae_metric: 0.1419 - val_loss: 0.0479 - val_mae_metric: 0.1568
#
# Epoch 00111: val_loss did not improve from 0.04585
# Epoch 112/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0466 - mae_metric: 0.1720 - val_loss: 0.0483 - val_mae_metric: 0.1512
#
# Epoch 00112: val_loss did not improve from 0.04585
# Epoch 113/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0442 - mae_metric: 0.1709 - val_loss: 0.0482 - val_mae_metric: 0.1488
#
# Epoch 00113: val_loss did not improve from 0.04585
# Epoch 114/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0374 - mae_metric: 0.1508 - val_loss: 0.0479 - val_mae_metric: 0.1512
#
# Epoch 00114: val_loss did not improve from 0.04585
# Epoch 115/200
# 108/108 [==============================] - 17s 154ms/step - loss: 0.0350 - mae_metric: 0.1497 - val_loss: 0.0510 - val_mae_metric: 0.1561
#
# Epoch 00115: val_loss did not improve from 0.04585
# Epoch 116/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0558 - mae_metric: 0.1869 - val_loss: 0.0493 - val_mae_metric: 0.1530
#
# Epoch 00116: val_loss did not improve from 0.04585
# Epoch 117/200
# 108/108 [==============================] - 17s 153ms/step - loss: 0.0408 - mae_metric: 0.1627 - val_loss: 0.0477 - val_mae_metric: 0.1560
#
# Epoch 00117: val_loss did not improve from 0.04585
#
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 118/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0420 - mae_metric: 0.1680 - val_loss: 0.0488 - val_mae_metric: 0.1608
#
# Epoch 00118: val_loss did not improve from 0.04585
# Epoch 119/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0423 - mae_metric: 0.1638 - val_loss: 0.0494 - val_mae_metric: 0.1578
#
# Epoch 00119: val_loss did not improve from 0.04585
# Epoch 120/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0368 - mae_metric: 0.1532 - val_loss: 0.0482 - val_mae_metric: 0.1511
#
# Epoch 00120: val_loss did not improve from 0.04585
# Epoch 121/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0432 - mae_metric: 0.1630 - val_loss: 0.0487 - val_mae_metric: 0.1549
#
# Epoch 00121: val_loss did not improve from 0.04585
# Epoch 122/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0449 - mae_metric: 0.1683 - val_loss: 0.0466 - val_mae_metric: 0.1495
#
# Epoch 00122: val_loss did not improve from 0.04585
# Epoch 123/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0394 - mae_metric: 0.1580 - val_loss: 0.0471 - val_mae_metric: 0.1514
#
# Epoch 00123: val_loss did not improve from 0.04585
# Epoch 124/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0421 - mae_metric: 0.1651 - val_loss: 0.0484 - val_mae_metric: 0.1501
#
# Epoch 00124: val_loss did not improve from 0.04585
# Epoch 125/200
# 108/108 [==============================] - 16s 152ms/step - loss: 0.0399 - mae_metric: 0.1569 - val_loss: 0.0469 - val_mae_metric: 0.1514
#
# Epoch 00125: val_loss did not improve from 0.04585
# Epoch 126/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0374 - mae_metric: 0.1519 - val_loss: 0.0497 - val_mae_metric: 0.1534
#
# Epoch 00126: val_loss did not improve from 0.04585
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 127/200
# 108/108 [==============================] - 16s 153ms/step - loss: 0.0429 - mae_metric: 0.1607 - val_loss: 0.0470 - val_mae_metric: 0.1558
#
# Epoch 00127: val_loss did not improve from 0.04585
# Epoch 128/200
# 108/108 [==============================] - 17s 157ms/step - loss: 0.0454 - mae_metric: 0.1706 - val_loss: 0.0480 - val_mae_metric: 0.1577
#
# Epoch 00128: val_loss did not improve from 0.04585
# Wall time: 35min 16s

# %% [markdown]
# Make a plot showing training history

# %%
fig = plt.figure(figsize = (6,6))
plt.subplot(121)
# summarize history for accuracy
plt.plot(history.history['mae_metric'])
plt.plot(history.history['val_mae_metric'])
plt.ylabel('Mean absolute error')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(122)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# Make a plot showing predicted wave heights versus observed
#
# Use the model to estimate wave height from every image (that number can be anything from 1 to the length of `test_X`)

# %%
pred_Y = np.squeeze(OWG.predict(test_X, batch_size = batch_size, verbose = True))
# Out:
# 72/72 [==============================] - 2s 19ms/step

# %% [markdown]
# Make a plot of observed versus estimated wave height

# %%
print ("[INFO] Plotting ...")     												        
fig, ax1 = plt.subplots(1,1, figsize = (6,6))
ax1.plot(test_Y, pred_Y, 'b.', alpha=0.5, label = 'Estimated')
ax1.plot(test_Y, test_Y, 'k-', label = 'Observed')
ax1.legend()
if category=='H':
   ax1.set_xlabel('Actual H (m)')
   ax1.set_ylabel('Estimated H (m)')
else:
   ax1.set_xlabel('Actual T (s)')
   ax1.set_ylabel('Estimated T (s)')    
plt.show()
# Out:
# [INFO] Plotting ...

# %% [markdown]
# Show a few augmanted test images and their estimates wave height (and observed wave height, for comparison)

# %%
rand_idx = np.random.choice(range(test_X.shape[0]), 9)
fig, m_axs = plt.subplots(3, 3, figsize = (16, 16))
for (idx, c_ax) in zip(rand_idx, m_axs.flatten()):
  c_ax.imshow(test_X[idx, :,:,0], cmap = 'gray')
  if category == 'H':
      c_ax.set_title('H: %0.3f\nPredicted H: %0.3f' % (test_Y[idx], pred_Y[idx]))
  else:
      c_ax.set_title('T: %0.3f\nPredicted T: %0.3f' % (test_Y[idx], pred_Y[idx]))
  
  c_ax.axis('off')
